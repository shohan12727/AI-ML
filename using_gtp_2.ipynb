# %% [markdown]
# <a href="https://colab.research.google.com/github/shohan12727/AI-ML/blob/main/using_gtp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="openai-community/gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
prompt = 'What is machine learning?'
output = pipe(prompt)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output[0]['generated_text'])
# Out:
# What is machine learning?
#
# Machine learning is a fundamental part of the computer experience, from how you interact with your keyboard to how you interact with the car.
#
# Machine learning is often used for learning about the world around you and how you interact with your computer.
#
# Machine learning is a process that involves a combination of machine learning techniques and computational power.
#
# Machine learning is about learning about the world. Machine learning is about understanding and understanding what is happening in your world. Machine learning is about learning about how you interact with your device. Machine learning is about understanding and understanding how you interact with your environment. Machine learning is about understanding and understanding what happens in your environment.
#
# ...
