# %%
print("hello king");
# Out:
# hello king

# %%
name = "Shohan king";
print(name);
# Out:
# Shohan king

# %%
age = 20
print(age)
# Out:
# 20

# %%
age = 20
name = "Gandu"
height = 5.6
is_passed = False
print(type(age), type(name), type(is_passed), type(height));
# Out:
# <class 'int'> <class 'str'> <class 'bool'> <class 'float'>

# %% [markdown]
# Taking input from input

# %%
name = input ("What is your name?")
print(name);
# Out:
# shohan

# %%
age = input("what is your age?")
print(age, type(age))
# Out:
# 20 <class 'str'>

# %%
age = input("what is your age?") # at first string 


age = int(age) # then it converted it into integer

print(age, type(age))
# Out:
# 20 <class 'int'>

# %% [markdown]
# **Operator**

# %%
x = 10; y = 3 
sum = x + y
sub = x - y 
mult = x * y 
div = round(x / y)

remin = x % y

print (sum, sub, mult, div, remin)
# Out:
# 13 7 30 3 1

# %%
x = 10; y = 3 

greater_then = x > y 
greater_then_or_equal = 10 >= 10

print(greater_then, greater_then_or_equal)
# Out:
# True True
